# %% [markdown]
# # Python Syllabus
#
# ## 1. Python Basics
# - [x] Introduction to Python
# - [x] Features of Python
# - [x] Python Installation
# - [x] Python IDE / Jupyter Notebook
# - [x] Comments
# - Variables
# - Constants
# - Keywords
# - Identifiers
#
# ## 2. Data Types ✅
# - [x] int
# - [x] float
# - complex
# - [x] bool
# - [x] str
# - list
# - tuple
# - set
# - dictionary
# - None
#
# ## 3. Input and Output ✅
# - [x] `print()`
# - [x] `input()`
# - [x] Type Conversion
# - [x] `int()`
# - [x] `float()`
# - [x] `str()`
# - [x] `bool()`
# - `isinstance()`
#
# ## 4. Operators ✅
# - [x] Arithmetic Operators
# - [x] Assignment Operators
# - [x] Comparison Operators
# - [x] Logical Operators
# - [x] Membership Operators
# - [x] Identity Operators
# - Bitwise Operators
#
# ## 5. Strings ✅
# - [x]  String Creation
# - [x]  String Indexing
# - [x]  String Slicing
# - [x]  String Concatenation
# - [x] String Methods
# - `upper()`
# - `lower()`
# - `strip()`
# - `replace()`
# - `split()`
# - `join()`
# - `startswith()`
# - `endswith()`
# - `isdigit()`
# - `isalpha()`
# - `isalnum()`
# - `isspace()`
#
# ## 6. Conditional Statements  ✅
# - [x] `if`
# - [x] `if-else`
# - [x] `if-elif-else`
# - [x] Nested `if`
# - Ternary Operator
#
# ## 7. Loops
# - `for` Loop
# - `while` Loop
# - `range()`
# - `break`
# - `continue`
# - `pass`
# - Nested Loops
#
# ## 8. Lists  ✅
# - [x] Creating Lists
# - [x] Indexing
# - [x] Slicing
# - [x] Adding Elements : **append(), insert(), extend()**
# - [x] Removing Elements :  **remove(), pop(), clear()**
# - [x] List Methods : index(), **count(), sort(), reverse(), copy()**
# - List Comprehension
#
# ## 9. Tuples  ✅
# - [x] Creating Tuples
# - [x] Indexing
# - [x] Slicing
# - [x] Tuple Methods :  **count(),index()**
# - [x] Tuple Unpacking
#
# ## 10. Sets  ✅
# - [x] Creating Sets
# - [x] Adding and Removing Elements :  **add(), update(), remove(),discard() ,pop(), clear()**
# - [x] Set Methods : **copy()**
# - [x] Union
# - [x] Intersection
# - [x] Difference
# -  Symmetric Difference :  **symmetric_difference() intersection_update() difference_update() symmetric_difference_update()**
#
# ## 11. Dictionaries  ✅
# - [x] Creating Dictionaries
# - [x] Accessing Values : **get(), keys(), values(), items()**
# - [x] Adding and Updating Values : **update(), setdefault()**
# - [x] Removing Items  : **pop(), popitem(), clear()**
# - [x] Dictionary Methods :  **copy()**
# - Dictionary Comprehension
#
# ## 12. Functions
# - Defining Functions
# - Function Arguments
# - Parameters
# - Return Statement
# - Default Arguments
# - Keyword Arguments
# - `*args`
# - `**kwargs`
# - Lambda Functions
# - Scope of Variables
#
# ## 13. Exception Handling
# - Errors and Exceptions
# - `try`
# - `except`
# - `else`
# - `finally`
# - `raise`
#
# ## 14. File Handling
# - Opening Files
# - Reading Files
# - Writing Files
# - Appending Data
# - `with` Statement
#
# ## 15. Object-Oriented Programming
# - Classes
# - Objects
# - Constructor
# - `self`
# - Instance Variables
# - Methods
# - Inheritance
# - Encapsulation
# - Polymorphism
# - Abstraction
#
# ## 16. Modules and Packages
# - Importing Modules
# - Built-in Modules
# - Creating Modules
# - Packages
# - `pip`

# %% [markdown]
# ### Python Assignments
#
# - [x] 1. Python Variables & Type Casting - 30 Practice Questions
# - [x] 2. Python Advanced Variables, Data Types & Type Casting - 50 Coding Questions
# - [x] 3. Python String Indexing, Functions, Methods & Operators - 50 Coding Questions
# - [x] 4. Python Operator Questions - 50
# - [x] 5. Python Operators Practice - 50 Questions
# - [x] 6. Python Operators - 20 Practice Questions
# - [x] 7. Python Operators Practice Questions - 40
# - [x] 8. Python list tuple set 30 practice question
# - [x] 9. Python Dictionary - 30 Practice Questions
# - [x] 10.Python if, else, and elif - 20 Practice Questions

# %% [markdown]
# ### Python Mini Projects
#
# 1. Student Result Management System
# 2. ATM System
# 3. Employee Salary Calculator
# 4. Electricity Bill Generator
# 5. Movie Ticket Booking System
# 6. Online Shopping Discount System
# 7. Loan Eligibility Checker
# 8. Hospital Management System
# 9. Restaurant Billing System
# 10. School Admission System
