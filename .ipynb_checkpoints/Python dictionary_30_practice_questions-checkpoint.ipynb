# %% [markdown]
# ## Python Dictionary - 30 Practice Questions

# %% [markdown]
# **Q1. Create a dictionary containing student name, roll number, course, and marks. Print the complete dictionary.**

# %%
student={
 "name" : "Ashish",
 "roll number" : "101",
 "course": "ABC",
 "marks": "60"
}
print(student)
# Out:
# {'name': 'Ashish', 'roll number': '101', 'course': 'ABC', 'marks': '60'}

# %% [markdown]
# **Q2. Create a dictionary with five programming languages as keys and their creators as values.**

# %%
languages = {
    "Python": "Guido van Rossum",
    "C": "Dennis Ritchie",
    "C++": "Bjarne Stroustrup",
    "Java": "James Gosling",
    "JavaScript": "Brendan Eich"
}
languages
# Out:
# {'Python': 'Guido van Rossum',
#  'C': 'Dennis Ritchie',
#  'C++': 'Bjarne Stroustrup',
#  'Java': 'James Gosling',
#  'JavaScript': 'Brendan Eich'}

# %% [markdown]
# **Q3. Create an empty dictionary and add three key-value pairs one by one.**

# %%
student={}
student['name']="Ashish"
student['roll number']="201"
student['course']="ABC"
student
# Out:
# {'name': 'Ashish', 'roll number': '201', 'course': 'ABC'}

# %% [markdown]
# **Q4. Create a dictionary of employee details and access the employee's salary using its key.**

# %%
employee = {
   "id": "60",
   "name" : "Ashish",
   "salary" : "101",
   "department": "ABC"
}
employee['salary']
# Out:
# '101'

# %% [markdown]
# **Q5. Create a dictionary and print all its keys using the keys() method.**

# %%
employee = {
   "id": "60",
   "name" : "Ashish",
   "salary" : "101",
   "department": "ABC"
}
employee.keys()
# Out:
# dict_keys(['id', 'name', 'salary', 'department'])

# %% [markdown]
# **Q6. Create a dictionary and print all its values using the values() method.**

# %%
employee = {
   "id": "60",
   "name" : "Ashish",
   "salary" : "101",
   "department": "ABC"
}
employee.values()
# Out:
# dict_values(['60', 'Ashish', '101', 'ABC'])

# %%
**Q7. Create a dictionary and print all key-value pairs using the items() method.**

# %%
employee = {
   "id": "60",
   "name" : "Ashish",
   "salary" : "101",
   "department": "ABC"
}
employee.items()
# Out:
# dict_items([('id', '60'), ('name', 'Ashish'), ('salary', '101'), ('department', 'ABC')])

# %% [markdown]
# **Q8. Create a dictionary of three products and their prices. Update the price of one product.**

# %%
products = {
    "Pen": 10,
    "Notebook": 50,
    "Pencil": 5
}
products['Pencil']=10
products
# Out:
# {'Pen': 10, 'Notebook': 50, 'Pencil': 10}

# %% [markdown]
# **Q9. Create a dictionary and add a new key called 'city' with any city name as its value.**

# %%
student={
 "name" : "Ashish",
 "roll number" : "101",
 "course": "ABC",
 "marks": "60"
}
student["city"]="delhi"
student
# Out:
# {'name': 'Ashish',
#  'roll number': '101',
#  'course': 'ABC',
#  'marks': '60',
#  'city': 'delhi'}

# %% [markdown]
# **Q10. Create a dictionary and remove one key-value pair using pop().**

# %%
student={
 "name" : "Ashish",
 "roll number" : "101",
 "course" : "ABC",
 "marks" : "60",
 "city" : "delhi"
}
student.pop("marks")
student
# Out:
# {'name': 'Ashish', 'roll number': '101', 'course': 'ABC', 'city': 'delhi'}

# %% [markdown]
# **Q11. Create a dictionary and remove the last inserted item using popitem().**

# %%
student={
 "name" : "Ashish",
 "roll number" : "101",
 "course" : "ABC",
 "marks" : "60",
 "city" : "delhi"
}
student.popitem()
student
# Out:
# {'name': 'Ashish', 'roll number': '101', 'course': 'ABC', 'marks': '60'}

# %% [markdown]
# **Q12. Create a dictionary and delete a specific key using the del keyword**.

# %%
student={
 "name" : "Ashish",
 "roll number" : "101",
 "course" : "ABC",
 "marks" : "60",
 "city" : "delhi"
}
del student['course'];
student
# Out:
# {'name': 'Ashish', 'roll number': '101', 'marks': '60', 'city': 'delhi'}

# %% [markdown]
# **Q13. Create a dictionary and make a copy of it using the copy() method.**

# %%
student={
 "name" : "Ashish",
 "roll number" : "101",
 "course" : "ABC",
 "marks" : "60",
 "city" : "delhi"
}
new_student = student.copy();
new_student
# Out:
# {'name': 'Ashish',
#  'roll number': '101',
#  'course': 'ABC',
#  'marks': '60',
#  'city': 'delhi'}

# %% [markdown]
# **Q14. Create a dictionary and clear all its elements using the clear() method.**

# %%
student={
 "name" : "Ashish",
 "roll number" : "101",
 "course" : "ABC",
 "marks" : "60",
 "city" : "delhi"
}
student.clear();
student
# Out:
# {}

# %% [markdown]
# **Q15. Create a dictionary and use get() to access a value for an existing key.**

# %%
student={
 "name" : "Ashish",
 "roll number" : "101",
 "course" : "ABC",
 "marks" : "60",
 "city" : "delhi"
}
print(student.get("name"));
# Out:
# Ashish

# %% [markdown]
# **Q16. Use get() with a default value for a key that does not exist in the dictionary.**

# %%
student = {"name": "Rahul", "age": 20}
result = student.get("city", "Not Exist")
print(result)
# Out:
# Not Exist

# %% [markdown]
# **Q17. Create two dictionaries and merge the second dictionary into the first using update().**

# %%
student = {"name": "Rahul", "age": 20}
marks={"math":"40","sci":"23"}
student.update(marks)
student
# Out:
# {'name': 'Rahul', 'age': 20, 'math': '40', 'sci': '23'}

# %% [markdown]
# **Q18. Create a dictionary using fromkeys() with keys ['name', 'age', 'city'] and the default value 'Not Available'.**

# %%
keys = ['name', 'age', 'city']
print(student.fromkeys(keys, 'Not Available'))
# Out:
# {'name': 'Not Available', 'age': 'Not Available', 'city': 'Not Available'}

# %% [markdown]
# **Q19. Create a dictionary containing marks of five subjects and calculate the total marks.**

# %%
marks={
    "m1":45,
    "m2":46,
    "m3":37,
    "m4":63,
    "m5":78
}
print("sum : ",sum(marks.values()))
# Out:
# sum 269

# %% [markdown]
# **Q20. Create a dictionary containing marks of five subjects and calculate the average marks.**

# %%
marks={
    "m1":45,
    "m2":46,
    "m3":37,
    "m4":63,
    "m5":78
}
print("avg : ",sum(marks.values())/5)
# Out:
# avg :  53.8

# %% [markdown]
# **Q21. Create a dictionary of product prices and find the most expensive product.**

# %%
prices={
    "p1":45,
    "p2":46,
    "p3":37,
    "p4":63,
    "p5":78
}
print("Maximum Price :", max(marks.values()) )
# Out:
# avg : 78

# %% [markdown]
# **Q22. Create a dictionary of product prices and find the cheapest product.**

# %%
prices={
    "p1":45,
    "p2":46,
    "p3":37,
    "p4":63,
    "p5":78
}
print("minimum  price :", min(marks.values()) )
# Out:
# minimum  price : 37

# %% [markdown]
# **Q23. Create a dictionary containing student names as keys and marks as values. Find the student with the highest marks.**

# %%
student={
 "name" : "Ashish",
 "course" : "ABC",
 "marks" : "60",
 "city" : "delhi"
}
del student['course'];
student

# %% [markdown]
# **Q24. Create a dictionary containing student names as keys and marks as values. Find the student with the lowest marks.**

# %%
student = {
    "Aman": 85,
    "Riya": 92,
    "Rahul": 78,
    "Simran": 88
}
print(min(student.values()))
# Out:
# 78

# %% [markdown]
# **Q25. Create a nested dictionary containing details of three students. Each student should have name, age, and marks.**

# %%
students = {
    "student1": {"name": "Ashish", "marks": 85},
    "student2": {"name": "Aadi", "marks": 92},
    "student3": {"name": "Gaurav", "marks": 72},
}

print(students)
# Out:
# {'student1': {'name': 'Ashish', 'marks': 85}, 'student2': {'name': 'Aadi', 'marks': 92}, 'student3': {'name': 'Gaurav', 'marks': 72}}

# %% [markdown]
# **Q26. From a nested student dictionary, access and print the marks of the second student.**

# %%
students = {
    "student1": {"name": "Ashish", "marks": 85},
    "student2": {"name": "aadi", "marks": 92}
}

print(students["student2"]["marks"])
# Out:
# 92

# %% [markdown]
# **Q27. Create a dictionary containing a list as a value, such as subjects studied by a student. Print the second subject.**

# %%
student = {
    "subject": ["Math", "Science", "English", "Computer"]
}

print(student["subject"][1])
# Out:
# Science

# %% [markdown]
# **Q28. Create a dictionary from two lists: one list containing keys and another list containing values**.

# %%
keys = ["name","age","course","city"]
values = ["ashish","30","bca","delhi"]
student = dict(zip(keys, values))
student
# Out:
# {'name': 'ashish', 'age': '30', 'course': 'bca', 'city': 'delhi'}

# %% [markdown]
# **Q29. Write a program to check whether a given key exists in a dictionary.**

# %%
student={
 "name" : "Ashish",
 "course" : "ABC",
 "marks" : "60",
 "city" : "delhi"
}
print("course" in student.keys())
# Out:
# True

# %% [markdown]
# **Q30. Create a small Student Record Management program using a dictionary that can store a students name, roll number, course, marks, and result, then display the complete record.**

# %%
student = {
    "name": "Ashish",
    "roll number": 101,
    "course": "BCA",
    "marks": 85,
    "result": "Pass"
}

print("Student Record")
print("Name:", student["name"])
print("Roll Number:", student["roll number"])
print("Course:", student["course"])
print("Marks:", student["marks"])
print("Result:", student["result"])
# Out:
# Student Record
# Name: Ashish
# Roll Number: 101
# Course: BCA
# Marks: 85
# Result: Pass
