# %% [markdown]
# # String Exercise

# %% [markdown]
# **1. Write a Python program to print first character.**

# %%
name = "python"
print("print first character",name[0])
# Out:
# print first character p

# %% [markdown]
# **2. Write a Python program to print last character.**

# %%
name = "python"
print("print last character",name[-1])
# Out:
# print last character n

# %% [markdown]
# **3. Write a Python program to use positive indexing.**

# %%
name = "python"
print("positive indexing",name[2])
# Out:
# positive indexing t

# %% [markdown]
# **4. Write a Python program to use negative indexing.**

# %%
name = "python"
print("negative indexing",name[-2])
# Out:
# negative indexing o

# %% [markdown]
# **5. Write a Python program to slice first 5 characters.**

# %%
name = "python"
print("slice first 5 characters",name[:5])
# Out:
# slice first 5 characters pytho

# %% [markdown]
# **6. Write a Python program to reverse a string.**

# %%
name = "python"
print("reverse a string.",name[::-1])
# Out:
# reverse a string. nohtyp

# %% [markdown]
# **7. Write a Python program to print every second character.**

# %%
name = "python"
print("print every second character",name[::2])
# Out:
# print every second character pto

# %% [markdown]
# **8. Write a Python program to count vowels.**

# %%
text = "hello world"
sum=text.count('a')+text.count('i')+text.count('o')+text.count('u')+text.count('e')
print("print every second character",sum)
# Out:
# print every second character 3

# %% [markdown]
# **9. Write a Python program to check palindrome.**

# %%
text = input("Enter a word: ")
print("To check palindrome:" , text == text[::-1])
# Out:
# Enter a word:  level
# To check palindrome: True

# %% [markdown]
# **10. Write a Python program to check anagram.**

# %%
str1 = input("Enter first word: ")
str2 = input("Enter second word: ")

print("Anagram check " ,sorted(str1) == sorted(str2))
# Out:
# Enter first word:  listen
# Enter second word:  silent
# anagram check  True

# %% [markdown]
# **11. Write a Python program to convert to uppercase.**

# %%
name = "python"
print("Convert into uppercase:",name.upper())
# Out:
# Convert into uppercase: PYTHON

# %% [markdown]
# **12. Write a Python program to convert to lowercase.**

# %%
name = "PYTHON"
print("Convert into lowercase:",name.lower())
# Out:
# Convert into lowercase: python

# %% [markdown]
# **13. Write a Python program to use title().**

# %%
text = "Hello world"
print("Add as a title: ",text.title())
# Out:
# Add as a title:  Hello World

# %% [markdown]
# **14. Write a Python program to use capitalize().**

# %%
text = "hello world"
print("Captalize: ",text.capitalize())
# Out:
# Captalize:  Hello world

# %% [markdown]
# **15. Write a Python program to use swapcase().**

# %%
text = "hello world"
print("swapcase: ",text.swapcase())
# Out:
# swapcase:  HELLO WORLD

# %% [markdown]
# **16. Write a Python program to remove spaces with strip().**

# %%
text = "                 hello world                 "
text.strip()
# Out:
# 'hello world'

# %% [markdown]
# **17. Write a Python program to replace substring.**

# %%
text = "hello world"
print("Replace string: ",text.replace('hello','hi'))
# Out:
# Replace string:  hi world

# %% [markdown]
# **18. Write a Python program to find substring.**

# %%
text = "hello world"
print("Find string: ",text.find('w'))
# Out:
# Find string:  6

# %% [markdown]
# **19. Write a Python program to use index().**

# %%
name = "PYTHON"
print("Find index value:",name[1]);
# Out:
# Find index value: Y

# %% [markdown]
# **20. Write a Python program to count substring.**

# %%
text = "hello world"
print("Find string: ",text.count('o'))
# Out:
# Find string:  2

# %% [markdown]
# **21. Write a Python program to check startswith().**

# %%
text = "hello world"
print("Find string: ",text.endswith('d'))
# Out:
# Find string:  True

# %% [markdown]
# **22. Write a Python program to check endswith().**

# %%
text = "hello world"
print("Find string: ",text.startswith('h'))
# Out:
# Find string:  True

# %% [markdown]
# **23. Write a Python program to split string.**

# %%
text = "hello world"
print("Find string: ",text.split())
# Out:
# Find string:  ['hello', 'world']

# %% [markdown]
# **24. Write a Python program to join list.**

# %%
text =  ['hello', 'world']
print("-".join(text))
# Out:
# hello-world

# %% [markdown]
# **25. Write a Python program to check isalpha().**

# %%
text = "helloworld"
print("Find string: ",text.isalpha())
# Out:
# Find string:  True

# %% [markdown]
# **26. Write a Python program to check isdigit().**

# %%
text = "12345678"
print("Find string: ",text.isdigit())
# Out:
# Find string:  True

# %% [markdown]
# **27. Write a Python program to check isalnum().**

# %%
text = "hello world"
print("Find string: ",text.isalnum())
# Out:
# Find string:  False

# %% [markdown]
# **28. Write a Python program to check islower().**

# %%
text = "hello world"
print("Find string: ",text.islower())
# Out:
# Find string:  True

# %% [markdown]
# **29. Write a Python program to check isupper().**

# %%
text = "hello world"
print("Find string: ",text.isupper())
# Out:
# Find string:  False

# %% [markdown]
# **30. Write a Python program to check isspace().**

# %%
text = "hello world"
print("Find string: ",text.isspace())
# Out:
# Find string:  True

# %% [markdown]
# **31. Write a Python program to use len().**

# %%
text = "hello world"
print("Find string: ",len(text))
# Out:
# Find string:  11

# %% [markdown]
# **32. Write a Python program to use max().**

# %%
text = "hello world"
print("Find string: ",max(text))
# Out:
# Find string:  w

# %% [markdown]
# **33. Write a Python program to use min().**

# %%
text = "helloworld"
print("Find string: ",min(text))
# Out:
# Find string:  d

# %% [markdown]
# **34. Write a Python program to sort characters.**

# %%
text = "helloworld"
print("Find string: ",sorted(text))
# Out:
# Find string:  ['d', 'e', 'h', 'l', 'l', 'l', 'o', 'o', 'r', 'w']

# %% [markdown]
# **35. Write a Python program to take input().**

# %%
name = str(input("enter your name"));
name
# Out:
# enter your name monu
# 'monu'

# %% [markdown]
# **36. Write a Python program to use type().**

# %%
text = "helloworld"
print("Find string: ",type(text))
# Out:
# Find string:  <class 'str'>

# %% [markdown]
# **37. Write a Python program to + operator.**

# %%
a = "hello"
b = "world"
print(a+" " +b)
# Out:
# hello world

# %% [markdown]
# **38. Write a Python program to * operator.**

# %%
a = "hello"

print(a*2)
# Out:
# hellohello

# %% [markdown]
# **39. Write a Python program to in operator.**

# %%
text = "hello world"
print("Find string: ","hello" in text)
# Out:
# Find string:  True

# %% [markdown]
# **40. Write a Python program to not in operator.**

# %%
text = "hello world"
print("Find string: ","Hi"  not in text)
# Out:
# Find string:  True

# %% [markdown]
# **41. Write a Python program to == operator.**

# %%
str1 = "hello"
str2 = "hello"

print(str1 == str2)
# Out:
# True

# %% [markdown]
# **42. Write a Python program to != operator.**

# %%
str1 = "hello"
str2 = "Hello"

print(str1 != str2)
# Out:
# True

# %% [markdown]
# **43. Write a Python program to compare strings.**

# %%
str1 = input("Enter first string: ")
str2 = input("Enter second string: ")

print(str1 == str2)
# Out:
# Enter first string:  hi
# Enter second string:  hi
# True

# %% [markdown]
# **44. Write a Python program to concatenate names.**

# %%
first_name = input("Enter first name: ")
last_name = input("Enter last name: ")

full_name = first_name + " " + last_name
print(full_name)
# Out:
# Enter first name:  monu
# Enter last name:  thakur
# monu thakur

# %% [markdown]
# **45. Write a Python program to repeat string.**

# %%
text = "python"

print(text * 3)
# Out:
# pythonpythonpython

# %% [markdown]
# **46. Write a Python program to extract email username.**

# %%
text = "abc@gmqail.com"

print(text.split('@')[0])
# Out:
# abc

# %% [markdown]
# **47. Write a Python program to extract file extension.**

# %%
filename = "image.jpg"

print(filename.split('.')[1])
# Out:
# jpg

# %% [markdown]
# **48. Write a Python program to count words.**

# %%
text = "hello world"
print("Find string: ", len(text))
# Out:
# Find string:  11

# %% [markdown]
# **49. Write a Python program to reverse words.**

# %%
text = "hello world"
print("Find string: ",text[::-1])
# Out:
# Find string:  dlrow olleh

# %% [markdown]
# **50. Write a Python program to create password validator.**

# %%
password = input("Enter password: ")

print(
    len(password) >= 8
    and any(c.isupper() for c in password)
    and any(c.islower() for c in password)
    and any(c.isdigit() for c in password)
)
# Out:
# Enter password:  Hello232
# True
