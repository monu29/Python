# %% [markdown]
# **Q1. Write a Python expression to perform an arithmetic operation and predict the output.**

# %%
result = 10 + 8 * 2
print(result)
# Out:
# 26

# %% [markdown]
# **Q2. Write a Python expression to perform an arithmetic operation and predict the output.**

# %% [markdown]
# **Q3. Write a Python expression to perform an arithmetic operation and predict the output.**

# %% [markdown]
# **Q4. Write a Python expression to perform an arithmetic operation and predict the output.**

# %% [markdown]
# **Q5. Write a Python expression to perform an arithmetic operation and predict the output.**

# %% [markdown]
# **Q6. Write a Python expression to perform an arithmetic operation and predict the output.**

# %% [markdown]
# **Q7. Write a Python expression to perform an arithmetic operation and predict the output.**

# %% [markdown]
# **Q8. Write a Python expression to perform an arithmetic operation and predict the output.**

# %% [markdown]
# **Q9. Write a Python expression to perform an arithmetic operation and predict the output.**

# %% [markdown]
# **Q10. Write a Python expression to perform an arithmetic operation and predict the output.**

# %% [markdown]
# **Q11. Write a Python expression to perform an arithmetic operation and predict the output.**

# %% [markdown]
# ** Q12. Write a Python expression to perform an arithmetic operation and predict the output.**
