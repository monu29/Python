# %% [markdown]
# # <center>Python Operator Questions - 50</center>

# %% [markdown]
# ### **Topics Covered:** Arithmetic, Assignment, Comparison, Logical, Identity, Membership, Bitwise Operators

# %% [markdown]
# ## Arithmetic Operators

# %% [markdown]
# **Q1. What will be the output: `10 + 5 * 2` ?**

# %%
a = 10
b = 5
c = 2
result = a+b*c
result
# Out:
# 20

# %% [markdown]
# **Q2. Find the output:  `20 / 4 + 3 `**

# %%
a = 20
b = 4
c = 3
result = a/b+c
result
# Out:
# 8.0

# %% [markdown]
# **Q3. What is the difference between  `/` and  `//` operator in Python?**

# %% [markdown]
# | `/` Operator | `//` Operator |
# |---|---|
# | Used for normal division. | Used for floor division. |
# | Returns a decimal/float value. | Returns the floor value. |
# | Example: `10 / 3` = `3.333...` | Example: `10 // 3` = `3` |

# %% [markdown]
# **Q4. What will be the output:  `17 // 5` ?**

# %%
a = 17
b = 5
result = 17 // 5
result
# Out:
# 3

# %% [markdown]
# **Q5. What will be the output:  `17 % 5 ` ?**

# %%
a = 17
b = 5
result = 17 % 5
result
# Out:
# 2

# %% [markdown]
# **Q6. Write a program to take two numbers and print their sum, difference, product, and division.**

# %%
a = int(input("Enter the first number"))
b = int(input("Enter the second number"))

print('Sum: ' , a+b)
print('Difference: ' , a-b)
print('Product: ' , a*b)
print('Division: ' , a/b)
# Out:
# Enter the first number 2
# Enter the second number 3
# Sum:  5
# Difference:  -1
# Product:  6
# Division:  0.6666666666666666

# %% [markdown]
# **Q7. What will be the output: `2 ** 3 ** 2` ?**

# %%
a = 2
b = 3
c = 2
result = a ** b ** c
result
# Out:
# 512

# %% [markdown]
# **Q8. Write a program to calculate area of a rectangle using length and width.**

# %%
length = float(input("Enter length: "))
width = float(input("Enter width: "))

area = length * width

print("Area of rectangle:", area)
# Out:
# Enter length:  23
# Enter width:  20
# Area of rectangle: 460.0

# %% [markdown]
# **Q9. What will be the output: `50 - 5 * 6 + 10` ?**

# %%
a = 50
b = 5
c = 6
d = 10
result = a - b * c + d
result
# Out:
# 30

# %% [markdown]
#  **Q10. Why is modulus (%) operator used? Give one example.**

# %% [markdown]
# The modulus (`%`) operator is used to find the remainder after division.

# %%
a = 17
b = 3
result = a % b
result
# Out:
# 2

# %% [markdown]
# ## Assignment Operators

# %% [markdown]
# **Q11. What is the use of `=` operator in Python?**

# %% [markdown]
# The `=` operator is used to **assign** a value to a variable.

# %%
x = 10
print(x)
# Out:
# 10

# %% [markdown]
# **Q12. What will be the value of `x` after this code: `x = 10; x += 5` ?**

# %%
x = 10
x += 5
x
# Out:
# 15

# %% [markdown]
# **Q13. What will be the value of `y: y = 20; y -= 8` ?**

# %%
y = 20
y -= 8
y
# Out:
# 12

# %% [markdown]
# **Q14. What will be the output: `a = 4; a *= 3; print(a)`?**

# %%
a = 4
a *= 3
print(a)
# Out:
# 12

# %% [markdown]
# **Q15. What will be the output: `b = 15; b /= 3; print(b)` ?**

# %%
b = 15
b /= 3
print(b)
# Out:
# 5.0

# %% [markdown]
# **Q16. What is the difference between `x = x + 1` and `x += 1`?**

# %%
x = 5
print(x + 1) 
x += 1
print(x)
# Out:
# 6
# 6

# %% [markdown]
# Both statements do the **same thing**: they increase the value of `x` by `1`.
#
# | `x = x + 1` | `x += 1` |
# |---|---|
# | Adds `1` to `x` and assigns the result back to `x`. | Short form of `x = x + 1`. |
# | Longer way | Shorter way |

# %% [markdown]
# **Q17. Write a program using `+=` to add marks of `3` subjects.**

# %%
total = 0
total += 67
total += 75
total += 45
print(total)
# Out:
# 187

# %% [markdown]
# **Q18. What will be the value of `n: n = 10; n %= 4`?**

# %%
n = 10
n %= 4
print(n)
# Out:
# 2

# %% [markdown]
# **Q19. What will be the value of `p: p = 2; p **= 4` ?**

# %%
p = 2
p **= 4
print(p)
# Out:
# 16

# %% [markdown]
# **Q20. Find error if any: `5 = x`**

# %% [markdown]
# Yes, there is an error.
#
# **Explanation:**
# In Python, we assign a value using the equal (`=`) sign, and the variable should be on the left side.
#
# **Example**
# `x=5`

# %% [markdown]
# ## Comparison Operators

# %% [markdown]
# **Q21. What will be the output: `10 > 5` ?**

# %%
a = 10
b = 5
result = a > b
print(result)
# Out:
# True

# %% [markdown]
# **Q22. What will be the output: `10 == "10"` ?**

# %%
print(10 == "10")
# Out:
# False

# %% [markdown]
# **Q23. What is the difference between `=` and `==` in Python?**

# %% [markdown]
# | `=` | `==` |
# |---|---|
# | It is an assignment operator. | It is a comparison operator. |
# | It is used to assign a value to a variable. | It is used to compare two values. |
# | Example: `x = 10` | Example: `x == 10` |
# | It does not return `True` or `False`. | It returns `True` or `False`. |

# %% [markdown]
# **Q24. What will be the output: `7 != 7` ?**

# %%
print(7 != 7)
# Out:
# False

# %% [markdown]
# **Q25. Write a program to check if `a` number is greater than `100`.**

# %%
a = int(input("Enter the number"))
print(a>100)
# Out:
# Enter the number 30
# False

# %% [markdown]
# **Q26. What will be the output: `15 >= 15` ?**

# %%
print(15 >= 15)
# Out:
# True

# %% [markdown]
# **Q27. What will be the output: `8 < 3` ?**

# %%
print(8 < 3 )
# Out:
# False

# %% [markdown]
# **Q28. Write a program to compare marks of two students and print who scored more.**

# %%
stu1 = 78
stu2 = 68

print("Highest score:", max(stu1, stu2))
# Out:
# Highest score: 78

# %% [markdown]
# **Q29. What will be the output: `"apple" == "Apple"` ?**

# %%
print("apple" == "Apple")
# Out:
# False

# %% [markdown]
# **Q30. Why do comparison operators return `True` or `False`?**

# %% [markdown]
# Because comparison operators compare two values. The result of the comparison can be correct or incorrect, so Python represents it as `True` or `False`.

# %% [markdown]
# ## Logical Operators

# %% [markdown]
# **Q31. What will be the output: `True` and `False`?**

# %% [markdown]
# Output: `False`
# | `A` | `B` | `A and B` |
# |---|---|---|
# |  `False`| `False`|  `False`|
# |  `False`| `True` |  `False`|
# |  `True` | `False`|  `False`|
# |  `True` | `True` |  `True` |

# %% [markdown]
# **Q32. What will be the output: `True` or `False` ?**

# %% [markdown]
# Output: `True`
# | `A` | `B` | `A or B` |
# |---|---|---|
# |  `False`| `False`|  `False`|
# |  `False`| `True` |  `True`|
# |  `True` | `False`|  `True`|
# |  `True` | `True` |  `True` |

# %% [markdown]
# **Q33. What will be the output: not True ?**

# %%
print(not True)
# Out:
# False

# %% [markdown]
# **Q34. Find the output:  `10 > 5 and 20 > 10 `**

# %%
print(10 > 5 and 20 > 10 )
# Out:
# True

# %% [markdown]
# **Q35. Find the output:  `10 < 5 or 20 > 10 `**

# %%
print(10 < 5 or 20 > 10)
# Out:
# True

# %% [markdown]
# **Q36. Write a program to check if age is between  `18` and  `60` using and operator.**

# %%
age = 30
print(age > 18 and age < 60)
# Out:
# True

# %% [markdown]
# **Q37. Write a program to check if a number is less than `0` or greater than  `100` using  `or` operator.**

# %%
a = 20
print(a < 0 or a > 100)
# Out:
# False

# %% [markdown]
# **Q38. What will be the output:  `not(5 > 2)` ?**

# %%
print(not(5 > 2))
# Out:
# False

# %% [markdown]
# **Q39. What is the difference between  `and` and  `or`?**

# %% [markdown]
# `and` → Returns `True` only when both conditions are `True`.<br>
# `or` → Returns `True` when at least one condition is `True`.

# %%
print(True and False) 
print(True or False)
# Out:
# False
# True

# %% [markdown]
# **Q40. Give one real-life example of logical operator.**

# %% [markdown]
# I can do better programming if I have knowledge and I practice regularly.

# %%
knowledge = True
practice = True
print(knowledge and practice)
# Out:
# True

# %% [markdown]
# ## Identity, Membership and Bitwise Operators

# %% [markdown]
# **Q41. What will be the output: `a = [1,2]; b = a; print(a is b)` ?**

# %%
a = [1,2]
b = a
print(a is b)
# Out:
# True

# %% [markdown]
# **Q42. What will be the output: `a = [1,2]; b = [1,2]; print(a == b)` ?**

# %%
a = [1,2]
b = [1,2]
print(a == b)
# Out:
# True

# %% [markdown]
# **Q43. What is the difference between `is` and `==`?**

# %% [markdown]
# `==` checks whether two values are equal.<br>
# `is` checks whether two variables refer to the same object in memory.

# %%
a = [1, 2]
b = [1, 2]

print(a == b)  
print(a is b)
# Out:
# True
# False

# %% [markdown]
# **Q44. What will be the output: `"a" in "apple"` ?**

# %%
print("a" in "apple")
# Out:
# True

# %% [markdown]
# **Q45. What will be the output: `5 in [1, 2, 3, 4]` ?**

# %%
print(5 in [1, 2, 3, 4])
# Out:
# False

# %% [markdown]
# **Q46. Write a program to check if a name exists in a list of students.**

# %%
student=['aman','rakesh','arun','dev']
print('arun' in student)
# Out:
# True

# %% [markdown]
# **Q47. What will be the output: `5 & 3` ?**

# %%
print(5 & 3)
# Out:
# 1

# %% [markdown]
# **Q48. What will be the output: `5 | 3` ?**

# %%
print(5 | 3)
# Out:
# 7

# %% [markdown]
# **Q49. What will be the output: `5 ^ 3` ?**

# %%
print(5 ^  3)
# Out:
# 6

# %% [markdown]
# **Q50. What will be the output: `8 >> 1` ?**

# %%
print(8 >> 1)
# Out:
# 4
