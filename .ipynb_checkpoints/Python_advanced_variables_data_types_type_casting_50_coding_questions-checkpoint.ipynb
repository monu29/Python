# %% [markdown]
# # Python Advanced Variables, Data Types & Type Casting - 50 Coding Questions

# %% [markdown]
# **1. Declare int, float, str, bool variables.**

# %%
a = 10         #int
b = 12.2       #float
c = "python"   #string
d = True       #bool

# %% [markdown]
# **2. Print data types using type().**

# %%
a = 10
print(type(a))

b = 10.5
print(type(b))

c = "Python"
print(type(c))

d = True
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# **3. Store employee details in variables.**

# %%
id = 41
name = "Tarun"
age = 25
salary = 35000
department = 'IT'


print("Employee ID :", id)
print("Employee Name :", name)
print("Employee Age :", age)
print("Employee Salary :", salary)
print("Department :", department)
# Out:
# Employee ID : 41
# Employee Name : Tarun
# Employee Age : 25
# Employee Salary : 35000
# Department : IT

# %% [markdown]
# **4. Swap two integers without third variable.**

# %%
a = 14
b = 23

# Swap values
a, b = b, a

print("a :", a)
print("b :", b)
# Out:
# a : 23
# b : 14

# %% [markdown]
# **5. Swap two strings.**

# %%
a = "Hello"
b = "World"

# Swap values
a, b = b, a

print("a :", a)
print("b :", b)
# Out:
# a : World
# b : Hello

# %% [markdown]
# **6. Convert int to float.**

# %%
a = 10  #int
b = float(a)
print(type(b))
# Out:
# <class 'float'>

# %% [markdown]
# **7. Convert float to int.**

# %%
a = 10.0  #float
b = int(a)
print(type(b))
# Out:
# <class 'int'>

# %% [markdown]
# **8. Convert '250' to int.**

# %%
a = '250'  #str
b = int(a)
print(b)
print(type(b))
# Out:
# 250
# <class 'int'>

# %% [markdown]
# **9. Convert  `'45.75' ` to  `float `.**

# %%
a = '45.75'  #str
b = float(a)
print(b)
print(type(b))
# Out:
# 45.75
# <class 'float'>

# %% [markdown]
# **10. Convert `int` to `str`.**

# %%
a = 45  #int
b = str(a)
print(b)
print(type(b))
# Out:
# 45
# <class 'str'>

# %% [markdown]
# **11. Convert float to str.**

# %%
a = 45.75  #float
b = str(a)
print(b)
print(type(b))
# Out:
# 45.75
# <class 'str'>

# %% [markdown]
# **12. Convert bool to int.**

# %%
a = True  #bool
b = int(a)
print(b)
print(type(b))
# Out:
# 1
# <class 'int'>

# %% [markdown]
# **13. Convert int to bool.**

# %%
a = 1  #int
b = bool(a)
print(b)
print(type(b))

# %% [markdown]
# **14. Convert empty string to bool.**

# %%
a = ''  #str
b = bool(a)
print(b)
print(type(b))
# Out:
# False
# <class 'bool'>

# %% [markdown]
# **15. Convert non-empty string to bool.**

# %%
a = 'Python'  #str
b = bool(a)
print(b)
print(type(b))
# Out:
# True
# <class 'bool'>

# %% [markdown]
# **16. Take int input and print square.**

# %%
a = int(input("Enter the value"))
square= a*a
print('Square :',square)
# Out:
# Enter the value 3
# Square : 9

# %% [markdown]
# **17. Take float input and calculate circle area.**

# %%
r = float(input("Enter the value"))
circleArea = 3.14 * r * r
print('Circle area :',circleArea)
# Out:
# Enter the value 2
# Circle area : 12.56

# %% [markdown]
# **18. Take string input and print length.**

# %%
str1 = str(input("Enter the value"))

print('Circle area :', len(str1))
# Out:
# Enter the value python
# Circle area : 6

# %% [markdown]
# **19. Take age input and convert to int.**

# %%
a = int(input("Enter the value"))
print(type(a))
# Out:
# Enter the value 2
# <class 'int'>

# %% [markdown]
# **20. Take price input and convert to float.**

# %%
price = float(input("Enter the value"))
print(type(price))
# Out:
# Enter the value 23
# <class 'float'>

# %% [markdown]
# **21. Predict type(100).**

# %%
print(type(100))
# Out:
# <class 'int'>

# %% [markdown]
# **22. Predict type(100.0)**

# %%
print(type(100.0))
# Out:
# <class 'float'>

# %% [markdown]
# **23. Predict type(True).**

# %%
print(type(True))
# Out:
# <class 'bool'>

# %% [markdown]
# **24. Predict type('100').**

# %%
print(type('100'))
# Out:
# <class 'str'>

# %% [markdown]
# **25. Predict int(9.99).**

# %%
print(int(9.99))
# Out:
# 9

# %% [markdown]
# **26. Predict float(15).**

# %%
print(float(15))
# Out:
# 15.0

# %% [markdown]
# **27. Predict str(False).**

# %%
print(str(False))
# Out:
# False

# %% [markdown]
# **28. Predict bool(0).**

# %%
print(bool(0))
# Out:
# False

# %% [markdown]
# **29. Predict bool(-5).**

# %%
print( bool(-5))
# Out:
# True

# %% [markdown]
# **30. Predict bool([]).**

# %%
print(  bool([]))
# Out:
# False

# %% [markdown]
# **31. Convert binary '1010' to decimal.**

# %%
a = "1010"
b = float(a)
print(b)
# Out:
# 1010.0

# %% [markdown]
# **32. Convert hex 'A' to decimal.**

# %%
print(int('A', 16))
# Out:
# A 16

# %% [markdown]
# **33. Add two numeric strings correctly.**

# %%
a = "23"
b = "24"
c = int(a) + int(b)
print(c)
# Out:
# 47

# %% [markdown]
# **34. Concatenate two numeric strings.**

# %%
a = "23"
b = "24"
c = a + b
print(c)
# Out:
# 2324

# %% [markdown]
# **35. Average of three numbers.**

# %%
a = 2
b = 4
c = 3
c =  (a + b + c) / 3
print(c)
# Out:
# 3.0

# %% [markdown]
# **36. Simple interest.**

# %%
P = 5000
R = 5
T = 2

SI = (P * R * T) / 100
print(SI)
# Out:
# 500.0

# %% [markdown]
# **37. BMI calculation.**

# %%
weight = 60
height = 1.7

bmi = weight / (height ** 2)
print(bmi)
# Out:
# 20.761245674740486

# %% [markdown]
# **38. Percentage calculation.**

# %%
obtained_marks = 450
total_marks = 500

percentage = (obtained_marks / total_marks) * 100
print(percentage)
# Out:
# 90.0

# %% [markdown]
# **39. Adult check.**

# %%
age = 18
print(age >= 18)
# Out:
# True

# %% [markdown]
# **40. Seconds to HH:MM:SS.**

# %%
seconds = 10200
hrs = 10200 // 3600
mins = seconds // 60
print(f"{hrs}:{mins}:{seconds}")
# Out:
# 2:170:10200

# %% [markdown]
# **41. Celsius to Fahrenheit.**

# %%
#°F=(°C×9/5)+32

celsius = 25
fahrenheit = (celsius * 9/5)  +32
print(Fahrenheit)
# Out:
# 77.0

# %% [markdown]
# **42. Display types using isinstance().**

# %%
x = 25
print(isinstance(x, int))
print(isinstance(x, float))
# Out:
# True
# False

# %% [markdown]
# **43. Difference between '5'+'5' and 5+5.**

# %%
print('5' + '5')   #these are string values 
print(5 + 5)    #these are integer value
# Out:
# 55
# 10

# %% [markdown]
# **44. Convert 0/1 to bool.**

# %%
print(bool(0/1))
# Out:
# False

# %% [markdown]
# **45. Use uppercase constants.**

# %%
NAME="monu"
print(NAME)

# %% [markdown]
# **46. Multiple assignment.**

# %%
a,b =10,20
print(a)
print(b)
# Out:
# 10
# 20

# %% [markdown]
# **47. One value to multiple variables.**

# %%
a=b=c=10
print(a)
print(b)
print(c)
# Out:
# 10
# 10
# 10

# %% [markdown]
# **48. Change int→float→str.**

# %%
x=int(20)
y= float(x)
z=str(y)
print(type(x),x)
print(type(y),y)
print(type(z),z)
# Out:
# <class 'int'> 20
# <class 'float'> 20.0
# <class 'str'> 20.0

# %% [markdown]
# **49. Accept mixed inputs and convert.**

# %%
name = input("Enter your name: ")
age = int(input("Enter your age: "))
marks = float(input("Enter your marks: "))
# Out:
# Enter your name:  mmm
# Enter your age:  3
# Enter your marks:  33

# %% [markdown]
# **50. Create variables of all basic data types and display values.**

# %%
name = input("Enter your name: ")
age = int(input("Enter your age: "))
marks = float(input("Enter your marks: "))

print("Name:", name)
print("Age:", age)
print("Marks:", marks)
# Out:
# Enter your name:  mmm
# Enter your age:  34
# Enter your marks:  456
# Name: mmm
# Age: 34
# Marks: 456.0
